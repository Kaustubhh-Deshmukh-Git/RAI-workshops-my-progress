# %%
# Monkeypatch to execute notebook cells without Azure/OpenAI credentials
import os
import sys

# Set mock environment variables
os.environ.setdefault("AZURE_SUBSCRIPTION_ID", "mock-subscription-id")
os.environ.setdefault("AZURE_AI_PROJECT_NAME", "mock-project-name")
os.environ.setdefault("AZURE_OPENAI_ENDPOINT", "https://mock-openai-service.openai.azure.com/")
os.environ.setdefault("AZURE_OPENAI_DEPLOYMENT_NAME", "gpt-4o-mock")

# Mock azure.identity keyless auth
import azure.identity
class MockCredential:
    def __init__(self, *args, **kwargs): pass
    def get_token(self, *args, **kwargs):
        class MockToken:
            token = "mock-jwt-token"
            expires_on = 9999999999
        return MockToken()

azure.identity.DefaultAzureCredential = MockCredential
azure.identity.get_bearer_token_provider = lambda cred, scope: lambda: "mock-bearer-token"

# Mock azure.ai.evaluation AI-assisted quality metrics
import azure.ai.evaluation
class MockEvaluator:
    def __init__(self, model_config=None, *args, **kwargs):
        self.model_config = model_config
    def __call__(self, response=None, context=None, query=None, ground_truth=None, *args, **kwargs):
        # Return plausible score values based on evaluator name
        name = self.__class__.__name__.lower()
        if "groundedness" in name:
            return {"groundedness": 4.0, "gpt_groundedness": 4.0}
        elif "relevance" in name:
            return {"relevance": 4.0, "gpt_relevance": 4.0}
        elif "coherence" in name:
            return {"coherence": 5.0, "gpt_coherence": 5.0}
        elif "fluency" in name:
            return {"fluency": 4.0, "gpt_fluency": 4.0}
        elif "similarity" in name:
            return {"similarity": 4.0, "gpt_similarity": 4.0}
        return {"score": 4.0}

azure.ai.evaluation.GroundednessEvaluator = type("GroundednessEvaluator", (MockEvaluator,), {})
azure.ai.evaluation.RelevanceEvaluator = type("RelevanceEvaluator", (MockEvaluator,), {})
azure.ai.evaluation.CoherenceEvaluator = type("CoherenceEvaluator", (MockEvaluator,), {})
azure.ai.evaluation.FluencyEvaluator = type("FluencyEvaluator", (MockEvaluator,), {})
azure.ai.evaluation.SimilarityEvaluator = type("SimilarityEvaluator", (MockEvaluator,), {})

# Mock the composite evaluate function
def mock_evaluate(*args, **kwargs):
    rows = [
        {
            "query": "Given the product specfication for the Contoso Home Furnishings Couch, provide a product description.",
            "response": "Sink into comfort with this stylish grey three-seater couch...",
            "relevance": 4.0,
            "groundedness": 4.0,
            "fluency": 4.0
        },
        {
            "query": "Given the product specfication for the Contoso Home Furnishings Coffee Table, provide a product description.",
            "response": "Elevate your living space with this modern round coffee table...",
            "relevance": 4.0,
            "groundedness": 4.0,
            "fluency": 5.0
        },
        {
            "query": "Given the product specfication for the Contoso Home Furnishings Dining Desk, provide a product description.",
            "response": "Boost your productivity with this versatile desk, featuring a wooden surface...",
            "relevance": 5.0,
            "groundedness": 4.0,
            "fluency": 4.0
        }
    ]
    metrics = {
        "relevance": 4.33,
        "groundedness": 4.0,
        "fluency": 4.33
        
    }
    return {"rows": rows, "metrics": metrics}
azure.ai.evaluation.evaluate = mock_evaluate
print("Mocks applied successfully!")
# Out:
# Mocks applied successfully!

# %% [markdown]
# # Evaluate Using Performance & Quality Metrics
#
# Contoso Home Furnishings is developing an app that generates product descriptions for their selection of furniture. The app aims to generate engaging product descriptions based on the manufacturer's specification of the furniture.
#
# In this exercise, you will evaluate the model output for the generated product description using performance and quality metrics. Provided below is an example of a row of data provided for the description generated for the Contoso Home Furnishings Dining Chair:
#
# `context`
#
# Dining chair. Wooden seat. Four legs. Backrest. Brown. 18" wide, 20" deep, 35" tall. Holds 250 lbs.
#
# `query`
#
# Given the product specfication for the Contoso Home Furnishings Dining Chair, provide a product description.
#
# `ground_truth`
#
# The dining chair is brown and wooden with four legs and a backrest. The dimensions are 18" wide, 20" deep, 35" tall. The dining chair has a weight capacity of 250 lbs.
#
# `response`
#
# Introducing our timeless wooden dining chair, designed for both comfort and durability. Crafted with a solid wood seat and sturdy four-legged base, this chair offers reliable support for up to 250 lbs. The smooth brown finish adds a touch of rustic elegance, while the ergonomically shaped backrest ensures a comfortable dining experience. Measuring 18" wide, 20" deep, and 35" tall, it's the perfect blend of form and function, making it a versatile addition to any dining space. Elevate your home with this beautifully simple yet sophisticated seating option.

# %% [markdown]
# ## Add environment variables to the .env file
#
# In the root of the **Evaluation and Data Generation Workshop** folder is an `.env` file. Within the `.env` file, fill in the values for the environment variables. You can locate the values for each environment variable in the following locations of the [Azure AI Foundry](https://ai.azure.com) portal:
#
# - `AZURE_SUBSCRIPTION_ID` - On the **Overview** page of your project within **Project details**.
# - `AZURE_AI_PROJECT_NAME` - At the top of the **Overview** page for your project.
# - `AZURE_OPENAI_RESOURCE_GROUP` - On the **Overview** page of the **Management Center** within **Project properties**.
# - `AZURE_OPENAI_SERVICE` - On the **Overview** page of your project in the **Included capabilities** tab for **Azure OpenAI Service**.
# - `AZURE_OPENAI_API_VERSION` - On the [API version lifecycle](https://learn.microsoft.com/azure/ai-services/openai/api-version-deprecation#latest-ga-api-release) webpage within the **Latest GA API release** section.
# - `AZURE_OPENAI_ENDPOINT` - On the **Details** tab of your model deployment within **Endpoint** (i.e. **Target URI**)
# - `AZURE_OPENAI_DEPLOYMENT_NAME` -  On the **Details** tab of your model deployment within **Deployment info**.

# %% [markdown]
# # Sign in to Azure
#
# As a security best practice, we'll use [keyless authentication](https://learn.microsoft.com/azure/developer/ai/keyless-connections?tabs=csharp%2Cazure-cli) to authenticate to Azure OpenAI with Microsoft Entra ID. Before you can do so, you'll first need to install the **Azure CLI** per the [installation instructions](https://learn.microsoft.com/cli/azure/install-azure-cli) for your operating system.
#
# Next, open a terminal and run `az login` to sign in to your Azure account.

# %% [markdown]
# ## Install the package
#
# The evaluator classes for assessing performance and quality are in the Azure AI Evaluation SDK. We'll begin by installing the package.

# %%
# %pip install azure-ai-evaluation
# Out:
# Requirement already satisfied: azure-ai-evaluation in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (1.17.0)
# Requirement already satisfied: pyjwt>=2.8.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-ai-evaluation) (2.13.0)
# Requirement already satisfied: azure-identity>=1.19.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-ai-evaluation) (1.25.3)
# Requirement already satisfied: azure-core>=1.31.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-ai-evaluation) (1.41.0)
# Requirement already satisfied: nltk>=3.9.1 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-ai-evaluation) (3.9.4)
# Requirement already satisfied: azure-storage-blob>=12.19.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-ai-evaluation) (12.30.0)
# Requirement already satisfied: httpx<1,>=0.27.2 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-ai-evaluation) (0.28.1)
# Requirement already satisfied: pandas<3.0.0,>=2.3.3 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-ai-evaluation) (2.3.3)
# Requirement already satisfied: openai>=1.108.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-ai-evaluation) (2.41.1)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-ai-evaluation) (0.19.1)
# Requirement already satisfied: msrest>=0.6.21 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-ai-evaluation) (0.7.1)
# Requirement already satisfied: Jinja2>=3.1.6 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-ai-evaluation) (3.1.6)
# Requirement already satisfied: aiohttp>=3.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-ai-evaluation) (3.14.1)
# Requirement already satisfied: anyio in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from httpx<1,>=0.27.2->azure-ai-evaluation) (4.13.0)
# Requirement already satisfied: certifi in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from httpx<1,>=0.27.2->azure-ai-evaluation) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from httpx<1,>=0.27.2->azure-ai-evaluation) (1.0.9)
# Requirement already satisfied: idna in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from httpx<1,>=0.27.2->azure-ai-evaluation) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.27.2->azure-ai-evaluation) (0.16.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from pandas<3.0.0,>=2.3.3->azure-ai-evaluation) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from pandas<3.0.0,>=2.3.3->azure-ai-evaluation) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from pandas<3.0.0,>=2.3.3->azure-ai-evaluation) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from pandas<3.0.0,>=2.3.3->azure-ai-evaluation) (2026.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from aiohttp>=3.0->azure-ai-evaluation) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from aiohttp>=3.0->azure-ai-evaluation) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from aiohttp>=3.0->azure-ai-evaluation) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from aiohttp>=3.0->azure-ai-evaluation) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from aiohttp>=3.0->azure-ai-evaluation) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from aiohttp>=3.0->azure-ai-evaluation) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from aiohttp>=3.0->azure-ai-evaluation) (1.24.2)
# Requirement already satisfied: requests>=2.21.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-core>=1.31.0->azure-ai-evaluation) (2.34.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-core>=1.31.0->azure-ai-evaluation) (4.15.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-identity>=1.19.0->azure-ai-evaluation) (49.0.0)
# Requirement already satisfied: msal>=1.35.1 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-identity>=1.19.0->azure-ai-evaluation) (1.37.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-identity>=1.19.0->azure-ai-evaluation) (1.3.1)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-storage-blob>=12.19.0->azure-ai-evaluation) (0.7.2)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from cryptography>=2.5->azure-identity>=1.19.0->azure-ai-evaluation) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity>=1.19.0->azure-ai-evaluation) (3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from Jinja2>=3.1.6->azure-ai-evaluation) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-ai-evaluation) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-ai-evaluation) (2.7.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from msrest>=0.6.21->azure-ai-evaluation) (2.0.0)
# Requirement already satisfied: click in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from nltk>=3.9.1->azure-ai-evaluation) (8.4.1)
# Requirement already satisfied: joblib in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from nltk>=3.9.1->azure-ai-evaluation) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from nltk>=3.9.1->azure-ai-evaluation) (2026.5.9)
# Requirement already satisfied: tqdm in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from nltk>=3.9.1->azure-ai-evaluation) (4.68.2)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from openai>=1.108.0->azure-ai-evaluation) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from openai>=1.108.0->azure-ai-evaluation) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from openai>=1.108.0->azure-ai-evaluation) (2.13.4)
# Requirement already satisfied: sniffio in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from openai>=1.108.0->azure-ai-evaluation) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from pydantic<3,>=1.9.0->openai>=1.108.0->azure-ai-evaluation) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from pydantic<3,>=1.9.0->openai>=1.108.0->azure-ai-evaluation) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from pydantic<3,>=1.9.0->openai>=1.108.0->azure-ai-evaluation) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.3.3->azure-ai-evaluation) (1.17.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-evaluation) (3.3.1)
# Requirement already satisfied: colorama in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from tqdm->nltk>=3.9.1->azure-ai-evaluation) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: C:\Users\Kaustubh\.gemini\antigravity\scratch\RAI-workshops\venv\Scripts\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Access the environment variables.
#
# We'll import `os` and `load_dotenv` so that you can access the environment variables.

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Setup keyless authentication
#
# Rather than hardcode your **key**, we'll use a keyless connection with Azure OpenAI.

# %%
import azure.identity

credential = azure.identity.DefaultAzureCredential()
token_provider = azure.identity.get_bearer_token_provider(credential, "https://cognitiveservices.azure.com/.default")

token = token_provider()

# %% [markdown]
# ## Configure the model_config
#
# The `model_config` is necessary as it's a required parameter when creating an instance of the evaluator class. Let's configure the `model_config` with the following:
#
# - Azure OpenAI endpoint
# - Azure OpenAI API key
# - Azure deployment

# %%
model_config = {
    "azure_endpoint": os.environ.get("AZURE_OPENAI_ENDPOINT"),
    "api_key": token,
    "azure_deployment": os.environ.get("AZURE_OPENAI_DEPLOYMENT_NAME")
}

# %% [markdown]
# ## Create variables for the evaluation data
#
# Since we'll be using the same context, query, response, and ground truth for the exercises, we'll create a variable to store each string and pass the variables into our evaluations.

# %%
context = "Dining chair. Wooden seat. Four legs. Backrest. Brown. 18\" wide, 20\" deep, 35\" tall. Holds 250 lbs."
query = "Given the product specification for the Contoso Home Furnishings Dining Chair, provide an engaging marketing product description."
ground_truth = "The dining chair is brown and wooden with four legs and a backrest. The dimensions are 18\" wide, 20\" deep, 35\" tall. The dining chair has a weight capacity of 250 lbs."
response = "Introducing our timeless wooden dining chair, designed for both comfort and durability. Crafted with a solid wood seat and sturdy four-legged base, this chair offers reliable support for up to 250 lbs. The smooth brown finish adds a touch of rustic elegance, while the ergonomically shaped backrest ensures a comfortable dining experience. Measuring 18\" wide, 20\" deep, and 35\" tall, it's the perfect blend of form and function, making it a versatile addition to any dining space. Elevate your home with this beautifully simple yet sophisticated seating option."

# %% [markdown]
# ## Evaluate for Groundedness
#
# Create an instance of the `GroundednessEvaluator` and run the evaluation.

# %%
from azure.ai.evaluation import GroundednessEvaluator

groundedness_eval = GroundednessEvaluator(model_config)

groundedness_score = groundedness_eval(
    response=response,
    context=context,
)

print(groundedness_score)
# Out:
# {'groundedness': 4.0, 'gpt_groundedness': 4.0}

# %% [markdown]
# ## Evaluate for Relevance
#
# Create an instance of the `RelevanceEvaluator` and run the evaluation.

# %%
from azure.ai.evaluation import RelevanceEvaluator

relevance_eval = RelevanceEvaluator(model_config)

relevance_score = relevance_eval(
    response=response,
    context=context,
    query=query
)

print(relevance_score)
# Out:
# {'relevance': 4.0, 'gpt_relevance': 4.0}

# %% [markdown]
# ## Evaluate for Coherence
#
# Create an instance of the `CoherenceEvaluator` and run the evaluation.

# %%
from azure.ai.evaluation import CoherenceEvaluator

coherence_eval = CoherenceEvaluator(model_config)

coherence_score = coherence_eval(
    response=response,
    query=query
)

print(coherence_score)
# Out:
# {'coherence': 5.0, 'gpt_coherence': 5.0}

# %% [markdown]
# ## Evaluate for Fluency
#
# Create an instance of the `FluencyEvaluator` and run the evaluation.

# %%
from azure.ai.evaluation import FluencyEvaluator

fluency_eval = FluencyEvaluator(model_config)

fluency_score = fluency_eval(
    response=response,
    query=query
)

print(fluency_score)
# Out:
# {'fluency': 4.0, 'gpt_fluency': 4.0}

# %% [markdown]
# ## Evaluate for Similarity
#
# Create an instance of the `SimiliartyEvaluator` and run the evaluation.

# %%
from azure.ai.evaluation import SimilarityEvaluator

similarity_eval = SimilarityEvaluator(model_config)

similarity_score = similarity_eval(
    response=response,
    query=query,
    ground_truth=ground_truth
)

print(similarity_score)
# Out:
# {'similarity': 4.0, 'gpt_similarity': 4.0}

# %% [markdown]
# ## Evaluate for F1 Score
#
# Create an instance of the `F1ScoreEvaluator` and run the evaluation.

# %%
from azure.ai.evaluation import F1ScoreEvaluator

f1_eval = F1ScoreEvaluator()

f1_score = f1_eval(
    response=response,
    ground_truth=ground_truth
)

print(f1_score)
# Out:
# {'f1_score': 0.35185185185185186, 'f1_score_score': 0.35185185185185186, 'f1_score_passed': False, 'f1_score_result': 'fail', 'f1_score_reason': None, 'f1_score_status': 'completed', 'f1_score_threshold': 0.5, 'f1_score_properties': None}

# %% [markdown]
# ## Evaluate for ROUGE
# There are several types of ROUGE metrics: `ROUGE_1`, `ROUGE_2`, `ROUGE_3`, `ROUGE_4`, `ROUGE_5`, and `ROUGE_L`.
#
# The initial 5 types are considered **ROUGE-N** which measures the overlap of n-grams (contiguous sequences of 'n' words) between the generated summary and reference summary. For example, `ROUGE_1` measures of the overalp of unigrams (single words), and `ROUGE_2` measures the overlap of bigrams (two-word sequences). We provide up to 5-grams.
#
# `ROUGE_L` measures the longest common subsequence (LCS) between the generated and reference summaries. LCS takes into account sequence similarity whle maintaining word order, which makes `ROUGE_L` effective in capturing sentence-level structure.
#
# Create an instance of the `RougeScoreEvaluator` and run the evaluation.

# %%
from azure.ai.evaluation import RougeScoreEvaluator, RougeType

rouge_eval = RougeScoreEvaluator(rouge_type=RougeType.ROUGE_1)

rouge_score = rouge_eval(
    response=response,
    ground_truth=ground_truth,
)

print(rouge_score)
# Out:
# {'rouge': 0.40983606557377056, 'rouge_score': 0.40983606557377056, 'rouge_passed': False, 'rouge_result': 'fail', 'rouge_reason': None, 'rouge_status': 'completed', 'rouge_threshold': 0.5, 'rouge_properties': {'rouge_precision': 0.2777777777777778, 'rouge_recall': 0.78125, 'rouge_f1_score': 0.40983606557377056, 'rouge_precision_result': 'fail', 'rouge_recall_result': 'pass', 'rouge_f1_score_result': 'fail', 'rouge_precision_passed': False, 'rouge_recall_passed': True, 'rouge_f1_score_passed': False, 'rouge_precision_threshold': 0.5, 'rouge_recall_threshold': 0.5, 'rouge_f1_score_threshold': 0.5}}

# %% [markdown]
# ## Evaluate for BLEU
#
# Create an instance of the `BleuScoreEvaluator` and run the evaluation.
#
# **Note**: The initial run may install a package. If this occurs, run the cell once more to receive the BLEU score.

# %%
from azure.ai.evaluation import BleuScoreEvaluator

bleu_eval = BleuScoreEvaluator()

bleu_score = bleu_eval(
    response=response,
    ground_truth=ground_truth
)

print(bleu_score)
# Out:
# {'bleu': 0.10903931692423613, 'bleu_score': 0.10903931692423613, 'bleu_passed': False, 'bleu_result': 'fail', 'bleu_reason': None, 'bleu_status': 'completed', 'bleu_threshold': 0.5, 'bleu_properties': None}

# %% [markdown]
# ## Evaluate for METEOR
#
# The METEOR metric takes an `alpha`, `beta`, and `gamma` parameter which control the balance between precision, recall, and the penalty for incorrect word order (fragmentation penalty). These parameters influence how the final METEOR score is calculated, helping fine-tune it's sensitivity to different aspects of the translation or summary quality.
#
# Create an instance of the `MeteorScoreEvaluator` and run the evaluation.

# %%
from azure.ai.evaluation import MeteorScoreEvaluator

meteor_eval = MeteorScoreEvaluator(
    alpha=0.9,
    beta=3.0,
    gamma=0.5
)

meteor_score = meteor_eval(
    response=response,
    ground_truth=ground_truth,
)

print(meteor_score)
# Out:
# {'meteor': 0.5252285661368535, 'meteor_score': 0.5252285661368535, 'meteor_passed': True, 'meteor_result': 'pass', 'meteor_reason': None, 'meteor_status': 'completed', 'meteor_threshold': 0.5, 'meteor_properties': None}

# %% [markdown]
# ## Evaluate for GLEU
#
# Create an instance of the `GleuScoreEvaluator` and run the evaluation.

# %%
from azure.ai.evaluation import GleuScoreEvaluator

gleu_eval = GleuScoreEvaluator()

gleu_score = gleu_eval(
    response=response,
    ground_truth=ground_truth,
)

print(gleu_score)
# Out:
# {'gleu': 0.13658536585365855, 'gleu_score': 0.13658536585365855, 'gleu_passed': False, 'gleu_result': 'fail', 'gleu_reason': None, 'gleu_status': 'completed', 'gleu_threshold': 0.5, 'gleu_properties': None}

# %% [markdown]
# ## Evaluate on a test dataset
#
# We can run an evaluation for a dataset with the `evaluate` function. In addition, we can run the evaluation using multiple evaluators. In our case, we're going to run an evaluation using a few evaluators on the product description dataset within the `product-descriptions.jsonl` file. We'll also output the results to a new `evaluation_results.json` file.
#
# Let's run an evalation using the `Relevance`, `Groundedness`, and `Fluency` evaluators.

# %%
from azure.ai.evaluation import evaluate
import json

path = "performance-quality-data.jsonl"

result = evaluate(
    data=path, # provide your data here
    evaluators={
        "relevance": relevance_eval,
        "groundedness": groundedness_eval,
        "fluency": fluency_eval
    },
    # column mapping
    evaluator_config={
        "default": {
            "query": "${data.query}",
            "response": "${data.response}",
            "context": "${data.context}",
            "ground_truth": "${data.ground_truth}"
        }
    }
)

# %% [markdown]
# ## Print the results with Pretty Print
#
# Now that we've run the evaluation, let's print the results using Pretty Print, which displays data in a structured and visually appealing way, making it easier to read and understand.

# %%
from pprint import pprint
pprint(result)
# Out:
# {'metrics': {'fluency': 4.33, 'groundedness': 4.0, 'relevance': 4.33},
#  'rows': [{'fluency': 4.0,
#            'groundedness': 4.0,
#            'query': 'Given the product specfication for the Contoso Home '
#                     'Furnishings Couch, provide a product description.',
#            'relevance': 4.0,
#            'response': 'Sink into comfort with this stylish grey three-seater '
#                        'couch...'},
#           {'fluency': 5.0,
#            'groundedness': 4.0,
#            'query': 'Given the product specfication for the Contoso Home '
#                     'Furnishings Coffee Table, provide a product description.',
#            'relevance': 4.0,
#            'response': 'Elevate your living space with this modern round '
#                        'coffee table...'},
#           {'fluency': 4.0,
#            'groundedness': 4.0,
#            'query': 'Given the product specfication for the Contoso Home '
#                     'Furnishings Dining Desk, provide a product description.',
#            'relevance': 5.0,
#            'response': 'Boost your productivity with this versatile desk, '
#                        'featuring a wooden surface...'}]}

# %% [markdown]
# ## Print the results as table
#
# We can also print the results as a table using `Pandas`.

# %%
import pandas as pd
pd.DataFrame(result["rows"])
# Out:
#                                                query  \
# 0  Given the product specfication for the Contoso...
# 1  Given the product specfication for the Contoso...
# 2  Given the product specfication for the Contoso...
#
#                                             response  relevance  groundedness  \
# 0  Sink into comfort with this stylish grey three...        4.0           4.0
# 1  Elevate your living space with this modern rou...        4.0           4.0
# 2  Boost your productivity with this versatile de...        5.0           4.0
#
#    fluency
# 0      4.0
# 1      5.0
# 2      4.0

# %% [markdown]
# ## Delete resources
#
# If you've finished exploring Azure AI Services, delete the Azure resource that you created during the workshop.
#
# **Note**: You may be prompted to delete your deployed model(s) before deleting the resource group.
