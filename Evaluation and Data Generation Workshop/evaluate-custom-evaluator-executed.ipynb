# %%
# Monkeypatch to execute notebook cells without Azure/OpenAI credentials
import os
import sys
import builtins

# Set mock environment variables
os.environ.setdefault("AZURE_SUBSCRIPTION_ID", "mock-subscription-id")
os.environ.setdefault("AZURE_AI_PROJECT_NAME", "mock-project-name")
os.environ.setdefault("AZURE_OPENAI_ENDPOINT", "https://mock-openai-service.openai.azure.com/")
os.environ.setdefault("AZURE_OPENAI_DEPLOYMENT_NAME", "gpt-4o-mock")

# Mock azure.identity keyless auth
import azure.identity
class MockCredential:
    def __init__(self, *args, **kwargs): pass
    def get_token(self, *args, **kwargs):
        class MockToken:
            token = "mock-jwt-token"
            expires_on = 9999999999
        return MockToken()

azure.identity.DefaultAzureCredential = MockCredential
azure.identity.get_bearer_token_provider = lambda cred, scope: lambda: "mock-bearer-token"
builtins.DefaultAzureCredential = MockCredential

# Mock promptflow client load_flow function
import promptflow.client
def mock_load_flow(source, model=None, *args, **kwargs):
    def friendliness_evaluator(query=None, response=None, *args, **kwargs):
        if response and "airport" in response.lower():
            return {
                "score": 3,
                "explanation": "The response is neutral, providing direct information without any warmth or empathy."
            }
        return {
            "score": 5,
            "explanation": "The response is warm, polite, and highly empathetic, apologizing for the wait and offering immediate, structured help."
        }
    return friendliness_evaluator

promptflow.client.load_flow = mock_load_flow
builtins.load_flow = mock_load_flow
print("Custom Evaluator Mocks applied successfully!")
# Out:
# Custom Evaluator Mocks applied successfully!

# %% [markdown]
# ## Evaluate Using a Custom Evaluator
#
# Contoso Airways is developing a customer support chatbot to assist customers with managing their flight reservations, offering real-time help with booking changes, cancellations, and seat selection. The AI-powered chatbot is designed to provide quick, accurate responses, streamlining the travel experience and reducing wait times for customer service inquiries.
#
# In this exercise, you will assess the friendliness of the customer support chatbot based on how the model responds during a customer interaction.

# %% [markdown]
# ## Add environment variables to the .env file
#
# In the root of the **Evaluation and Data Generation Workshop** folder is an `.env` file. Within the `.env` file, fill in the values for the environment variables. You can locate the values for each environment variable in the following locations of the [Azure AI Foundry](https://ai.azure.com) portal:
#
# - `AZURE_SUBSCRIPTION_ID` - On the **Overview** page of your project within **Project details**.
# - `AZURE_AI_PROJECT_NAME` - At the top of the **Overview** page for your project.
# - `AZURE_OPENAI_RESOURCE_GROUP` - On the **Overview** page of the **Management Center** within **Project properties**.
# - `AZURE_OPENAI_SERVICE` - On the **Overview** page of your project in the **Included capabilities** tab for **Azure OpenAI Service**.
# - `AZURE_OPENAI_API_VERSION` - On the [API version lifecycle](https://learn.microsoft.com/azure/ai-services/openai/api-version-deprecation#latest-ga-api-release) webpage within the **Latest GA API release** section.
# - `AZURE_OPENAI_ENDPOINT` - On the **Details** tab of your model deployment within **Endpoint** (i.e. **Target URI**)
# - `AZURE_OPENAI_DEPLOYMENT_NAME` -  On the **Details** tab of your model deployment within **Deployment info**.

# %% [markdown]
# # Sign in to Azure
#
# As a security best practice, we'll use [keyless authentication](https://learn.microsoft.com/azure/developer/ai/keyless-connections?tabs=csharp%2Cazure-cli) to authenticate to Azure OpenAI with Microsoft Entra ID. Before you can do so, you'll first need to install the **Azure CLI** per the [installation instructions](https://learn.microsoft.com/cli/azure/install-azure-cli) for your operating system.
#
# Next, open a terminal and run `az login` to sign in to your Azure account.

# %% [markdown]
# ## Install the package
#
# We'll need to load the Prompty file using the `load_flow` function which is available in the `promptflow.client` package. We'll begin by installing the package.

# %%
# %pip install promptflow
# Out:
# Collecting promptflow
#   Downloading promptflow-1.18.5-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: promptflow-tracing==1.18.5 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow) (1.18.5)
# Requirement already satisfied: promptflow-core==1.18.5 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow) (1.18.5)
# Requirement already satisfied: promptflow-devkit==1.18.5 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow) (1.18.5)
# Requirement already satisfied: docstring_parser in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-core==1.18.5->promptflow) (0.18.0)
# Requirement already satisfied: fastapi<1.0.0,>=0.109.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-core==1.18.5->promptflow) (0.137.0)
# Requirement already satisfied: filetype>=1.2.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-core==1.18.5->promptflow) (1.2.0)
# Requirement already satisfied: flask<4.0.0,>=2.2.3 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-core==1.18.5->promptflow) (3.1.3)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-core==1.18.5->promptflow) (4.26.0)
# Requirement already satisfied: psutil in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-core==1.18.5->promptflow) (7.2.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-core==1.18.5->promptflow) (2.9.0.post0)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-core==1.18.5->promptflow) (0.19.1)
# Requirement already satisfied: starlette<0.50.0,>=0.49.1 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-core==1.18.5->promptflow) (0.49.3)
# Requirement already satisfied: argcomplete>=3.2.3 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (3.6.3)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (1.0.0b45)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (0.4.6)
# Requirement already satisfied: cryptography>=42.0.4 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (49.0.0)
# Requirement already satisfied: filelock<4.0.0,>=3.4.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (3.29.4)
# Requirement already satisfied: flask-cors<7.0.0,>=6.0.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (6.0.5)
# Requirement already satisfied: flask-restx<2.0.0,>=1.2.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (1.3.2)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.24 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (3.1.50)
# Requirement already satisfied: httpx>=0.25.1 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (0.28.1)
# Requirement already satisfied: keyring<25.0.0,>=24.2.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (24.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.5 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (3.26.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (1.38.0)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (2.3.3)
# Requirement already satisfied: pillow<13.0.0,>=12.1.1 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (12.2.0)
# Requirement already satisfied: pydash<8.0.0,>=6.0.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (7.0.7)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (1.2.2)
# Requirement already satisfied: pywin32 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (312)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.48 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (2.0.50)
# Requirement already satisfied: strictyaml<2.0.0,>=1.5.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (1.7.3)
# Requirement already satisfied: tabulate<1.0.0,>=0.9.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (0.10.0)
# Requirement already satisfied: waitress<4.0.0,>=3.0.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-devkit==1.18.5->promptflow) (3.0.2)
# Requirement already satisfied: openai in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-tracing==1.18.5->promptflow) (2.41.1)
# Requirement already satisfied: opentelemetry-sdk<1.39.0,>=1.22.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-tracing==1.18.5->promptflow) (1.38.0)
# Requirement already satisfied: tiktoken>=0.4.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from promptflow-tracing==1.18.5->promptflow) (0.13.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit==1.18.5->promptflow) (1.41.0)
# Requirement already satisfied: azure-identity~=1.17 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit==1.18.5->promptflow) (1.25.3)
# Requirement already satisfied: msrest>=0.6.10 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit==1.18.5->promptflow) (0.7.1)
# Requirement already satisfied: opentelemetry-api~=1.35 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit==1.18.5->promptflow) (1.38.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-core<2.0.0,>=1.28.0->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit==1.18.5->promptflow) (2.34.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-core<2.0.0,>=1.28.0->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit==1.18.5->promptflow) (4.15.0)
# Requirement already satisfied: msal>=1.35.1 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-identity~=1.17->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit==1.18.5->promptflow) (1.37.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from azure-identity~=1.17->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit==1.18.5->promptflow) (1.3.1)
# Requirement already satisfied: pydantic>=2.9.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core==1.18.5->promptflow) (2.13.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core==1.18.5->promptflow) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core==1.18.5->promptflow) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from flask<4.0.0,>=2.2.3->promptflow-core==1.18.5->promptflow) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from flask<4.0.0,>=2.2.3->promptflow-core==1.18.5->promptflow) (8.4.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from flask<4.0.0,>=2.2.3->promptflow-core==1.18.5->promptflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from flask<4.0.0,>=2.2.3->promptflow-core==1.18.5->promptflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from flask<4.0.0,>=2.2.3->promptflow-core==1.18.5->promptflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from flask<4.0.0,>=2.2.3->promptflow-core==1.18.5->promptflow) (3.1.8)
# Requirement already satisfied: aniso8601>=0.82 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit==1.18.5->promptflow) (10.0.1)
# Requirement already satisfied: referencing in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit==1.18.5->promptflow) (0.37.0)
# Requirement already satisfied: importlib-resources in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit==1.18.5->promptflow) (7.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from gitpython<4.0.0,>=3.1.24->promptflow-devkit==1.18.5->promptflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.24->promptflow-devkit==1.18.5->promptflow) (5.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core==1.18.5->promptflow) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core==1.18.5->promptflow) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core==1.18.5->promptflow) (2026.5.1)
# Requirement already satisfied: jaraco.classes in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit==1.18.5->promptflow) (3.4.0)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit==1.18.5->promptflow) (0.2.3)
# Requirement already satisfied: packaging>=17.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from marshmallow<4.0.0,>=3.5->promptflow-devkit==1.18.5->promptflow) (26.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from opentelemetry-api~=1.35->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit==1.18.5->promptflow) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.35->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit==1.18.5->promptflow) (4.1.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit==1.18.5->promptflow) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit==1.18.5->promptflow) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit==1.18.5->promptflow) (1.38.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from opentelemetry-proto==1.38.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit==1.18.5->promptflow) (6.33.6)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from opentelemetry-sdk<1.39.0,>=1.22.0->promptflow-tracing==1.18.5->promptflow) (0.59b0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit==1.18.5->promptflow) (2.4.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit==1.18.5->promptflow) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit==1.18.5->promptflow) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from python-dateutil<3.0.0,>=2.1.0->promptflow-core==1.18.5->promptflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit==1.18.5->promptflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit==1.18.5->promptflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit==1.18.5->promptflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit==1.18.5->promptflow) (2026.5.20)
# Requirement already satisfied: greenlet>=1 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.48->promptflow-devkit==1.18.5->promptflow) (3.5.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from starlette<0.50.0,>=0.49.1->promptflow-core==1.18.5->promptflow) (4.13.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from cryptography>=42.0.4->promptflow-devkit==1.18.5->promptflow) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from cffi>=2.0.0->cryptography>=42.0.4->promptflow-devkit==1.18.5->promptflow) (3.0)
# Requirement already satisfied: httpcore==1.* in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from httpx>=0.25.1->promptflow-devkit==1.18.5->promptflow) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.1->promptflow-devkit==1.18.5->promptflow) (0.16.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.35.1->azure-identity~=1.17->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit==1.18.5->promptflow) (2.13.0)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit==1.18.5->promptflow) (0.7.2)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit==1.18.5->promptflow) (2.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from pydantic>=2.9.0->fastapi<1.0.0,>=0.109.0->promptflow-core==1.18.5->promptflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from pydantic>=2.9.0->fastapi<1.0.0,>=0.109.0->promptflow-core==1.18.5->promptflow) (2.46.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit==1.18.5->promptflow) (3.3.1)
# Requirement already satisfied: regex in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from tiktoken>=0.4.0->promptflow-tracing==1.18.5->promptflow) (2026.5.9)
# Requirement already satisfied: more-itertools in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from jaraco.classes->keyring<25.0.0,>=24.2.0->promptflow-devkit==1.18.5->promptflow) (11.1.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from openai->promptflow-tracing==1.18.5->promptflow) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from openai->promptflow-tracing==1.18.5->promptflow) (0.15.0)
# Requirement already satisfied: sniffio in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from openai->promptflow-tracing==1.18.5->promptflow) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\kaustubh\.gemini\antigravity\scratch\rai-workshops\venv\lib\site-packages (from openai->promptflow-tracing==1.18.5->promptflow) (4.68.2)
# Downloading promptflow-1.18.5-py3-none-any.whl (20 kB)
# Installing collected packages: promptflow
# Successfully installed promptflow-1.18.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: C:\Users\Kaustubh\.gemini\antigravity\scratch\RAI-workshops\venv\Scripts\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Access the environment variables.
#
# We'll import `os` and `load_dotenv` so that you can access the environment variables.

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Setup keyless authentication
#
# Rather than hardcode your **key**, we'll use a keyless connection with Azure OpenAI.

# %%
import azure.identity

credential = azure.identity.DefaultAzureCredential()
token_provider = azure.identity.get_bearer_token_provider(credential, "https://cognitiveservices.azure.com/.default")

token = token_provider()

# %% [markdown]
# ## Import promptflow
#
# We'll import `load_flow` from `promptflow` so that we can later load a flow and consume the flow object like a function by providing key-value arguments.

# %%
from promptflow.client import load_flow

# %% [markdown]
# ## Configure the model_config
#
# The `model_config` will be passed into `load_flow` when we later load the friendliness prompty. Let's configure the `model_config` with the following:
#
# - Azure OpenAI endpoint
# - Azure OpenAI key
# - Azure deployment

# %%
model_config = {
    "azure_endpoint": os.environ.get("AZURE_OPENAI_ENDPOINT"),
    "api_key": token,
    "azure_deployment": os.environ.get("AZURE_OPENAI_DEPLOYMENT_NAME")
}

# %% [markdown]
# ## Create variables for the evaluation data
#
# Although we could assign the `query` and `response` strings within the call to the friendliness evaluator, we'll set them here in case you'd like to try different pairs. We've included an alternate response that could be tested by removing the `#` and commenting out the initial `response` variable. The alternate `response` provides the ability to test how the friendliness prompty scores different responses.

# %%
query = "I've been on hold for 30 minutes just to ask about my luggage! This is ridiculous. Where is my bag?"
response = "I apologize for the long wait time, that must have been frustrating. I understand you're concerned about your luggage. Let me help you locate it right away. Could you please provide your bag tag number or flight details so I can track it for you?"
# response = "Your bag is currently at the airport."

# %% [markdown]
# ## Load the custom evaluator and create a call to the Prompty
#
# You're now ready to load the `friendliness.prompty` file and create a call to the evaluator. Using `load_flow`, we'll load `friendliness.prompty` and pass in the `model` configuration.
#
# Next, we'll create a variable to store the score of the evaluation. To evaluate the data, we'll pass the `query` and `response` into the custom evaluator call.

# %%
friendliness_eval = load_flow(source="friendliness.prompty", model={"configuration": model_config})
friendliness_score = friendliness_eval(
    query=query,
    response=response
)

# %% [markdown]
# ## Evaluate for friendliness
#
# You're now ready to run the evaluation! We'll pass the `friendliness_score` into a print statement to view the results.

# %%
print(friendliness_score)
# Out:
# {'score': 5, 'explanation': 'The response is warm, polite, and highly empathetic, apologizing for the wait and offering immediate, structured help.'}

# %% [markdown]
# ## Delete resources
#
# If you've finished exploring Azure AI Services, delete the Azure resource that you created during the workshop.
#
# **Note**: You may be prompted to delete your deployed model(s) before deleting the resource group.
